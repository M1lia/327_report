# %%
# %matplotlib inline

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import plotly.graph_objs as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
import random
import os

# %%
df = pd.read_csv('full-gt.csv')

# %%
df.head(10)
# Out:
#                           filename  x_from  y_from  width  height sign_class  \
# 0  autosave01_02_2012_09_13_33.jpg     649     376     18      18        2_1
# 1  autosave01_02_2012_09_13_34.jpg     671     356     20      21        2_1
# 2  autosave01_02_2012_09_13_35.jpg     711     332     27      26        2_1
# 3  autosave01_02_2012_09_13_36.jpg     764     290     37      36        2_1
# 4  autosave01_02_2012_09_13_36.jpg     684     384     17      17       1_23
# 5  autosave01_02_2012_09_13_37.jpg     876     200     56      57        2_1
# 6  autosave01_02_2012_09_13_37.jpg     705     377     22      21       1_23
# 7  autosave01_02_2012_09_13_38.jpg     749     353     26      25       1_23
# 8  autosave01_02_2012_09_13_39.jpg     840     299     42      46       1_23
# 9  autosave01_02_2012_09_13_42.jpg     698     331     18      18       1_17
#
#    sign_id
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
# 5        0
# 6        1
# 7        1
# ...

# %%
df[(df['sign_class'] == '3_27') | (df['sign_class'] == '3_28') | (df['sign_class'] == '3_29') | (df['sign_class'] == '3_30' )]
# Out:
#                                  filename  x_from  y_from  width  height  \
# 260       autosave01_02_2012_09_20_33.jpg     752     370     16      18
# 262       autosave01_02_2012_09_20_34.jpg     823     347     25      27
# 264       autosave01_02_2012_09_20_35.jpg    1083     262     58      52
# 277       autosave01_02_2012_09_21_37.jpg     770     312     25      24
# 278       autosave01_02_2012_09_21_38.jpg     832     274     32      31
# ...                                   ...     ...     ...    ...     ...
# 104195  autosave24_10_2013_13_16_35_2.jpg     882     231     66      68
# 104207  autosave24_10_2013_13_17_00_0.jpg     720     341     29      29
# 104208  autosave24_10_2013_13_17_00_1.jpg     783     314     39      38
# 104209  autosave24_10_2013_13_17_00_2.jpg     872     277     51      51
# 104210  autosave24_10_2013_13_17_00_3.jpg    1125     178     90      86
#
#        sign_class  sign_id
# 260          3_27       57
# 262          3_27       57
# ...

# %%
df[(df['sign_class'] == '3_27')].count()
# Out:
# filename      3558
# x_from        3558
# y_from        3558
# width         3558
# height        3558
# sign_class    3558
# sign_id       3558
# dtype: int64

# %%
df[(df['sign_class'] == '3_27') | (df['sign_class'] == '3_28') | (df['sign_class'] == '3_29') | (df['sign_class'] == '3_30' )]['filename']
# Out:
# 260         autosave01_02_2012_09_20_33.jpg
# 262         autosave01_02_2012_09_20_34.jpg
# 264         autosave01_02_2012_09_20_35.jpg
# 277         autosave01_02_2012_09_21_37.jpg
# 278         autosave01_02_2012_09_21_38.jpg
#                         ...
# 104195    autosave24_10_2013_13_16_35_2.jpg
# 104207    autosave24_10_2013_13_17_00_0.jpg
# 104208    autosave24_10_2013_13_17_00_1.jpg
# 104209    autosave24_10_2013_13_17_00_2.jpg
# 104210    autosave24_10_2013_13_17_00_3.jpg
# Name: filename, Length: 4040, dtype: object

# %%
names = df[(df['sign_class'] == '3_27') | (df['sign_class'] == '3_28') | (df['sign_class'] == '3_29') | (df['sign_class'] == '3_30' )]['filename'].values.tolist()

# %%
names = df[(df['sign_class'] == '3_27')  ]['filename'].values.tolist()

# %%
names[:5]
# Out:
# ['autosave01_02_2012_09_20_33.jpg',
#  'autosave01_02_2012_09_20_34.jpg',
#  'autosave01_02_2012_09_20_35.jpg',
#  'autosave01_02_2012_09_21_37.jpg',
#  'autosave01_02_2012_09_21_38.jpg']

# %%
len(names)
# Out:
# 3558

# %%
idx = random.randint(0, len(names))
print(names[idx])
# Out:
# autosave21_01_2013_11_58_10_2.jpg

# %%
names = []

# %%
for filename in os.listdir(path_to_test):
    
        names.append(filename)

# %%
names.pop()
# Out:
# 'rtsd-frames2.zip'

# %%
df.head(5)
# Out:
#                           filename  x_from  y_from  width  height sign_class  \
# 0  autosave01_02_2012_09_13_33.jpg     649     376     18      18        2_1
# 1  autosave01_02_2012_09_13_34.jpg     671     356     20      21        2_1
# 2  autosave01_02_2012_09_13_35.jpg     711     332     27      26        2_1
# 3  autosave01_02_2012_09_13_36.jpg     764     290     37      36        2_1
# 4  autosave01_02_2012_09_13_36.jpg     684     384     17      17       1_23
#
#    sign_id
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1

# %%
t_df = df.loc[(df['filename'].isin(names)) & (df['sign_class'] == '3_27')]

# %%
t_df.head(5)
# Out:
#                             filename  x_from  y_from  width  height
# 359  autosave01_02_2012_09_23_57.jpg     968     310     41      41
# 361  autosave01_02_2012_09_23_58.jpg    1018     297     44      45
# 363  autosave01_02_2012_09_23_59.jpg    1055     280     52      51
# 365  autosave01_02_2012_09_24_02.jpg    1131     261     58      59
# 366  autosave01_02_2012_09_24_03.jpg    1149     258     61      62

# %%
ignore_idx =df[(df['sign_class'] == '3_27') | (df['sign_class'] == '3_28') | (df['sign_class'] == '3_29') | (df['sign_class'] == '3_30' )]['filename'].index.values
ignore_idx[:5]
# Out:
# array([260, 262, 264, 277, 278], dtype=int64)

# %%
names2 = []

# %%
ignore_idx = np.unique(ignore_idx)

# %%
names2 = df.sample(n = 3600, axis = 0, ignore_index = ignore_idx.all() )['filename'].values.tolist()
len(names2)
# Out:
# 3600

# %%
names_f = names + names2

# %%
len(names_f)
# Out:
# 7158

# %%
import zipfile

# %%
rtds_link = "C:\\Users\\Machine\\Downloads\\rtsd-frames.zip"

# %%
rtds_arch = zipfile.ZipFile(rtds_link, "r")

# %%
rtds_arch.printdir()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# rtsd-frames/autosave24_10_2012_10_40_38_3.jpg  2022-02-27 22:49:40       109089
# rtsd-frames/autosave24_10_2012_10_40_38_4.jpg  2022-02-27 22:49:40       107512
# rtsd-frames/autosave24_10_2012_10_40_40_0.jpg  2022-02-27 22:49:40       106202
# rtsd-frames/autosave24_10_2012_10_40_40_1.jpg  2022-02-27 22:49:40       100975
# rtsd-frames/autosave24_10_2012_10_40_40_2.jpg  2022-02-27 22:49:40       100291
# rtsd-frames/autosave24_10_2012_10_40_40_3.jpg  2022-02-27 22:49:40       101840
# rtsd-frames/autosave24_10_2012_10_40_40_4.jpg  2022-02-27 22:49:40       102868
# rtsd-frames/autosave24_10_2012_10_40_40_5.jpg  2022-02-27 22:49:40       104362
# ...

# %%
n=0
for i in range(len(names_f)):
    try:
        rtds_arch.extract('rtsd-frames/' + names_f[i], "C:\\Users\\Machine\\Downloads\\try_sign_detection\\327\\class_dataset" )
    except KeyError: 
        n += 1
        print(n )
rtds_arch.close()

# %%
path_to_test = "C:\\Users\\Machine\\Downloads\\try_sign_detection\\327\\class_dataset\\rtsd-frames"

# %%
len(names_f)
# Out:
# 7158

# %%
gt = pd.read_csv('full-gt.csv')

# %%
gt.head()
# Out:
#                           filename  x_from  y_from  width  height sign_class  \
# 0  autosave01_02_2012_09_13_33.jpg     649     376     18      18        2_1
# 1  autosave01_02_2012_09_13_34.jpg     671     356     20      21        2_1
# 2  autosave01_02_2012_09_13_35.jpg     711     332     27      26        2_1
# 3  autosave01_02_2012_09_13_36.jpg     764     290     37      36        2_1
# 4  autosave01_02_2012_09_13_36.jpg     684     384     17      17       1_23
#
#    sign_id
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1

# %%
path_to_final = "C:\\Users\\Machine\\Downloads\\try_sign_detection\\327\class_dataset\\rtsd-frames\\"

# %%
names_in_folder = []

# %%
for filename in os.listdir(path_to_final):
    
        names_in_folder.append(filename)

# %%
names_in_folder[:5]
# Out:
# ['autosave01_02_2012_09_13_45.jpg',
#  'autosave01_02_2012_09_17_25.jpg',
#  'autosave01_02_2012_09_17_43.jpg',
#  'autosave01_02_2012_09_18_37.jpg',
#  'autosave01_02_2012_09_18_41.jpg']

# %%
len(names_in_folder)
# Out:
# 6729

# %%
gt = gt.loc[gt['filename'].isin(names_in_folder)]

# %%
gt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14381 entries, 18 to 104355
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   filename    14381 non-null  object
#  1   x_from      14381 non-null  int64
#  2   y_from      14381 non-null  int64
#  3   width       14381 non-null  int64
#  4   height      14381 non-null  int64
#  5   sign_class  14381 non-null  object
#  6   sign_id     14381 non-null  int64
# dtypes: int64(5), object(2)
# memory usage: 898.8+ KB

# %%
gt.loc[gt['filename'].isin(names_in_folder)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14381 entries, 18 to 104355
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   filename    14381 non-null  object
#  1   x_from      14381 non-null  int64
#  2   y_from      14381 non-null  int64
#  3   width       14381 non-null  int64
#  4   height      14381 non-null  int64
#  5   sign_class  14381 non-null  object
#  6   sign_id     14381 non-null  int64
# dtypes: int64(5), object(2)
# memory usage: 898.8+ KB

# %%
gt.to_csv('data_4_cropping.csv')

# %%
gt = pd.read_csv('data_4_cropping.csv')

# %%
gt.head()
# Out:
#    Unnamed: 0                         filename  x_from  y_from  width  height  \
# 0          18  autosave01_02_2012_09_13_45.jpg    1076      32     75      70
# 1          19  autosave01_02_2012_09_13_45.jpg    1085     113     78      67
# 2          20  autosave01_02_2012_09_13_45.jpg    1085     186     80      31
# 3         134  autosave01_02_2012_09_17_25.jpg     968     257     37      38
# 4         135  autosave01_02_2012_09_17_25.jpg    1024     300     39      41
#
#   sign_class  sign_id
# 0       1_17        2
# 1       1_23        3
# 2      8_2_1        5
# 3        2_1       27
# 4     5_19_1       28

# %%
gt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14381 entries, 0 to 14380
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  14381 non-null  int64
#  1   filename    14381 non-null  object
#  2   x_from      14381 non-null  int64
#  3   y_from      14381 non-null  int64
#  4   width       14381 non-null  int64
#  5   height      14381 non-null  int64
#  6   sign_class  14381 non-null  object
#  7   sign_id     14381 non-null  int64
# dtypes: int64(6), object(2)
# memory usage: 898.9+ KB

# %%
gt_vis = gt.drop(['x_from', 'y_from', 'width', 'height', 'sign_id' ], axis = 1)

# %%
len(gt_vis['sign_class'].unique())
# Out:
# 160

# %%
gt.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
gt[gt['sign_class'] == '3_27']
# Out:
#                                 filename  x_from  y_from  width  height  \
# 14       autosave01_02_2012_09_20_33.jpg     752     370     16      18
# 16       autosave01_02_2012_09_20_34.jpg     823     347     25      27
# 18       autosave01_02_2012_09_20_35.jpg    1083     262     58      52
# 20       autosave01_02_2012_09_21_37.jpg     770     312     25      24
# 21       autosave01_02_2012_09_21_38.jpg     832     274     32      31
# ...                                  ...     ...     ...    ...     ...
# 14360  autosave24_10_2013_13_16_35_2.jpg     882     231     66      68
# 14361  autosave24_10_2013_13_17_00_0.jpg     720     341     29      29
# 14362  autosave24_10_2013_13_17_00_1.jpg     783     314     39      38
# 14363  autosave24_10_2013_13_17_00_2.jpg     872     277     51      51
# 14364  autosave24_10_2013_13_17_00_3.jpg    1125     178     90      86
#
#       sign_class  sign_id
# 14          3_27       57
# 16          3_27       57
# ...

# %% [markdown]
# ### Меняем sing_class на binary (Если 3_27, то 1, если остальное, то 0)

# %%
gt['sign_class'] = gt['sign_class'].apply(lambda s: 1 if s == '3_27' else 0)

# %%
gt = pd.read_csv('gt_balanced.csv')

# %%
gt
# Out:
#                                filename  x_from  y_from  width  height  \
# 0       autosave01_02_2012_09_20_33.jpg     752     370     16      18
# 1       autosave01_02_2012_09_20_34.jpg     823     347     25      27
# 2       autosave01_02_2012_09_20_35.jpg    1083     262     58      52
# 3       autosave01_02_2012_09_21_37.jpg     770     312     25      24
# 4       autosave01_02_2012_09_21_38.jpg     832     274     32      31
# ...                                 ...     ...     ...    ...     ...
# 7376  autosave24_10_2013_13_17_45_2.jpg     701     336     34      37
# 7377  autosave24_10_2013_13_18_04_2.jpg     774     373     36      35
# 7378  autosave24_10_2013_13_18_11_2.jpg     788     294     97      50
# 7379  autosave24_10_2013_13_18_11_2.jpg     815     344     48      25
# 7380  autosave24_10_2013_13_18_38_0.jpg     647     385     33      20
#
#       sign_class
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...

# %%
gt_vis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14381 entries, 0 to 14380
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   filename    14381 non-null  object
#  1   sign_class  14381 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 224.8+ KB

# %%
gt_vis = gt['sign_class']

# %%
gt_vis.plot.hist( )
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
idx_zero = gt[gt['sign_class'] == 0].index.to_list()[:1000]

# %%
len(idx_zero)
# Out:
# 1000

# %%
gt = gt.drop(labels = idx_zero ,axis = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14176\4011434079.py in <cell line: 1>()
# ----> 1 gt = gt.drop(labels = idx_zero ,axis = 0)
#
# NameError: name 'idx_zero' is not defined

# %%
gt.head(5)
# Out:
#                           filename  x_from  y_from  width  height  sign_class
# 0  autosave01_02_2012_09_20_33.jpg     752     370     16      18           1
# 1  autosave01_02_2012_09_20_34.jpg     823     347     25      27           1
# 2  autosave01_02_2012_09_20_35.jpg    1083     262     58      52           1
# 3  autosave01_02_2012_09_21_37.jpg     770     312     25      24           1
# 4  autosave01_02_2012_09_21_38.jpg     832     274     32      31           1

# %%
gt.head(5)
# Out:
#                            filename  x_from  y_from  width  height  sign_class
# 14  autosave01_02_2012_09_20_33.jpg     752     370     16      18           1
# 16  autosave01_02_2012_09_20_34.jpg     823     347     25      27           1
# 18  autosave01_02_2012_09_20_35.jpg    1083     262     58      52           1
# 20  autosave01_02_2012_09_21_37.jpg     770     312     25      24           1
# 21  autosave01_02_2012_09_21_38.jpg     832     274     32      31           1

# %%
gt.to_csv('gt_balanced.csv')

# %%
gt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7381 entries, 14 to 14380
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   filename    7381 non-null   object
#  1   x_from      7381 non-null   int64
#  2   y_from      7381 non-null   int64
#  3   width       7381 non-null   int64
#  4   height      7381 non-null   int64
#  5   sign_class  7381 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 403.6+ KB

# %% [markdown]
# ## Cropping

# %%
import cv2

# %%
names_gt = gt['filename'].values.tolist()

# %%
names_gt[:5]
# Out:
# ['autosave01_02_2012_09_20_33.jpg',
#  'autosave01_02_2012_09_20_34.jpg',
#  'autosave01_02_2012_09_20_35.jpg',
#  'autosave01_02_2012_09_21_37.jpg',
#  'autosave01_02_2012_09_21_38.jpg']

# %%
np.count_nonzero(gt['filename'].unique())
# Out:
# 4613

# %%
gt.iloc[7380]
# Out:
# filename      autosave24_10_2013_13_18_38_0.jpg
# x_from                                      647
# y_from                                      385
# width                                        33
# height                                       20
# sign_class                                    0
# Name: 7380, dtype: object

# %%
gt.shape[0]
# Out:
# 7381

# %%
rtds_link = "C:\\Users\\Machine\\Downloads\\rtsd-frames.zip"

# %%
rtds_arch = zipfile.ZipFile(rtds_link, "r")

# %%
rtds_arch.printdir()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
i
# Out:
# 7380

# %%
gt.iloc[i]['filename']
# Out:
# 'autosave24_10_2013_13_18_38_0.jpg'

# %%
n=0
for i in range(gt.shape[0]):
    try:
        rtds_arch.extract('rtsd-frames/' + gt.iloc[i]['filename'], "C:\\Users\\Machine\\Downloads\\try_sign_detection\\327\\class_dataset" )
    except KeyError: 
        n += 1
        print(n )
rtds_arch.close()

# %%
gt.columns
# Out:
# Index(['filename', 'x_from', 'y_from', 'width', 'height', 'sign_class'], dtype='object')

# %%
gt.reset_index(drop=True)
# Out:
#                                filename  x_from  y_from  width  height  \
# 0       autosave01_02_2012_09_20_33.jpg     752     370     16      18
# 1       autosave01_02_2012_09_20_34.jpg     823     347     25      27
# 2       autosave01_02_2012_09_20_35.jpg    1083     262     58      52
# 3       autosave01_02_2012_09_21_37.jpg     770     312     25      24
# 4       autosave01_02_2012_09_21_38.jpg     832     274     32      31
# ...                                 ...     ...     ...    ...     ...
# 7376  autosave24_10_2013_13_17_45_2.jpg     701     336     34      37
# 7377  autosave24_10_2013_13_18_04_2.jpg     774     373     36      35
# 7378  autosave24_10_2013_13_18_11_2.jpg     788     294     97      50
# 7379  autosave24_10_2013_13_18_11_2.jpg     815     344     48      25
# 7380  autosave24_10_2013_13_18_38_0.jpg     647     385     33      20
#
#       sign_class
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...

# %%
gt.iloc[558]
# Out:
# filename      autosave09_10_2012_08_41_01_1.jpg
# x_from                                      797
# y_from                                      329
# width                                        19
# height                                       18
# sign_class                                    1
# Name: 558, dtype: object

# %%
names_gt[558]
# Out:
# 'autosave09_10_2012_08_41_01_1.jpg'

# %%
gt.iloc[i]['filename']
# Out:
# 'autosave24_10_2013_13_18_38_0.jpg'

# %%
path_to_folder = "C:\\Users\\Machine\\Downloads\\try_sign_detection\\327\\class_dataset\\rtsd-frames\\"
path_to_saving = "C:\\Users\\Machine\\Downloads\\try_sign_detection\\327\\cropped_dataset\\"

# %%
for i in range(gt.shape[0]):
    img_ = cv2.imread(path_to_folder + str(gt.iloc[i]['filename']))
    width_ = gt.iloc[i]['width']
    height_ = gt.iloc[i]['height']
    x_ = gt.iloc[i]['x_from']
    y_ = gt.iloc[i]['y_from']
    
    crp_ = img_[y_:y_+height_, x_:x_+width_]
    cv2.imwrite(path_to_saving + gt.iloc[i]['filename'][:-4] + '__' + str(i) + '__' + str(gt.iloc[i]['sign_class']) + gt.iloc[i]['filename'][-4:], crp_)

# %%
gt.iloc[i]['filename'][:-4] + '_cls_' + str(gt.iloc[i]['sign_class']) + gt.iloc[i]['filename'][-4:]
# Out:
# 'autosave24_10_2013_13_18_38_0_cls_0.jpg'

# %%
img_ = cv2.imread(path_to_folder + str(names_gt[i]))

# %%
# Out:
# Index(['filename', 'x_from', 'y_from', 'width', 'height', 'sign_class'], dtype='object')

# %%
print(img_)
# Out:
# None

# %%
gt
# Out:
#                                filename  x_from  y_from  width  height  \
# 0       autosave01_02_2012_09_20_33.jpg     752     370     16      18
# 1       autosave01_02_2012_09_20_34.jpg     823     347     25      27
# 2       autosave01_02_2012_09_20_35.jpg    1083     262     58      52
# 3       autosave01_02_2012_09_21_37.jpg     770     312     25      24
# 4       autosave01_02_2012_09_21_38.jpg     832     274     32      31
# ...                                 ...     ...     ...    ...     ...
# 7376  autosave24_10_2013_13_17_45_2.jpg     701     336     34      37
# 7377  autosave24_10_2013_13_18_04_2.jpg     774     373     36      35
# 7378  autosave24_10_2013_13_18_11_2.jpg     788     294     97      50
# 7379  autosave24_10_2013_13_18_11_2.jpg     815     344     48      25
# 7380  autosave24_10_2013_13_18_38_0.jpg     647     385     33      20
#
#       sign_class
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...

# %%
cv2.resize?

# %%
im_res = r"C:\Users\Machine\Downloads\try_sign_detection\327\cropped_dataset\autosave16_04_2013_13_07_45_1.jpg"

# %%
img = cv2.imread(im_res)

# %%
plt.imshow?

# %%
plt.imshow(img)

# %%
height, width, channels = img.shape

# %%
height, width
# Out:
# (31, 25)

# %%
img2 = cv2.resize(img, (30, 30))

# %%
plt.imshow(img2)

# %% [markdown]
# Короче, чет не подумал о том, что все знаки будут разных размеров. При этом нужно, чтобы они были одного размера. В немецком датасете подаются на вход изображения 32 на 32. Сейчас сделаю что то подобное: удалю изображения меньше 21 на 21, а остальные ресайзну

# %%
n = 0
for filename in os.listdir(path_to_saving):
    img_ = cv2.imread(path_to_saving + filename)
    height, width, channels = img_.shape
    if (height < 21) or (width < 21):
        os.remove(path_to_saving + filename)
        
        n+=1

# %%
n
# Out:
# 1559

# %%
filename3 = r"C:\Users\Machine\Downloads\try_sign_detection\327\cropped_dataset\autosave01_02_2012_09_20_35__2__1.jpg"

# %%
int(filename3[len(str(filename)) - 5])
# Out:
# 1

# %%
z,x = 0,0
for filename in os.listdir(path_to_saving):
    if int(filename[len(str(filename)) - 5]) == 1:
        z += 1
    else:
        x += 1

# %%
print(f'3_27: {z}; another: {x}')
# Out:
# 3_27: 3015; another: 2807

# %% [markdown]
# ## resize all the rest crops of signs

# %%
crp_rsz_pth = "C:\\Users\\Machine\\Downloads\\try_sign_detection\\327\\cropped_and_resized\\"

# %%
for filename in os.listdir(path_to_saving):
    img_ = cv2.imread(path_to_saving + filename)
    img__ = cv2.resize(img_, (30, 30))
    cv2.imwrite(crp_rsz_pth + filename, img__)

# %%
img2 = cv2.resize(img, (30, 30))

# %%
cv2.imwrite(path_to_saving + gt.iloc[i]['filename'][:-4] + '__' + str(i) + '__' + str(gt.iloc[i]['sign_class']) + gt.iloc[i]['filename'][-4:], crp_)

# %% [markdown]
# ## test/train split

# %%
import shutil

# %%
cls_one = []
cls_two = []

# %%
for filename in os.listdir(crp_rsz_pth):
    if int(filename[len(str(filename)) - 5]) == 1:
        cls_one.append(crp_rsz_pth + filename)
    else:
        cls_two.append(crp_rsz_pth  + filename)

# %%
print(len(cls_one), len(cls_two))
# Out:
# 3015 2807

# %%
crp_rsz_pth
# Out:
# 'C:\\Users\\Machine\\Downloads\\try_sign_detection\\327\\cropped_and_resized\\'

# %%
all_X = cls_one+cls_two

# %%
all_X[0][len(all_X[0])-5]
# Out:
# '1'

# %%
all_y = []
for i in range(len(all_X)):
    all_y.append(all_X[i][len(all_X[i])-5])

# %%
# Out:
# 5822

# %%
for filename in os.listdir(crp_rsz_pth):
    if int(filename[len(str(filename)) - 5]) == 1:
        shutil.move(crp_rsz_pth + filename, )

# %%
shutil.move(src, dst, copy_function=copy2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     X, y, test_size=0.33, random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(all_X, all_y, test_size = 0.2, random_state = 42)

# %%
X_train[0]
# Out:
# 'C:\\Users\\Machine\\Downloads\\try_sign_detection\\327\\cropped_and_resized\\autosave02_10_2012_12_04_19_1__310__1.jpg'

# %%
test_dst =r"C:\Users\Machine\Downloads\try_sign_detection\327\final_dataset_v1\test"

# %%
train_dst = r"C:\Users\Machine\Downloads\try_sign_detection\327\final_dataset_v1\train"

# %%
train_dst
# Out:
# 'C:\\Users\\Machine\\Downloads\\try_sign_detection\\327\\final_dataset_v1\\train'

# %%
for i in X_train:
    shutil.move(i, train_dst )

# %%
for i in X_test:
    shutil.move(i, test_dst )

# %%
for filename in os.listdir(test_dst):
    if filename != '0' and filename != '1':
            
        if int(filename[len(str(filename)) - 5]) == 1:
            shutil.move(test_dst + '\\' + filename, test_1  )
        if int(filename[len(str(filename)) - 5]) == 0:
            shutil.move(test_dst + '\\' + filename, test_0  )

# %%
test_dst + '\str1'
# Out:
# 'C:\\Users\\Machine\\Downloads\\try_sign_detection\\327\\final_dataset_v1\\test\x01'

# %%
train_1 = r"C:\Users\Machine\Downloads\try_sign_detection\327\final_dataset_v1\train\1"

# %%
train_0 = r"C:\Users\Machine\Downloads\try_sign_detection\327\final_dataset_v1\train\0"

# %%
test_1 = r"C:\Users\Machine\Downloads\try_sign_detection\327\final_dataset_v1\test\1"

# %%
test_0 = r"C:\Users\Machine\Downloads\try_sign_detection\327\final_dataset_v1\test\1"

# %%
test_1
# Out:
# 'C:\\Users\\Machine\\Downloads\\try_sign_detection\\327\\final_dataset_v1\\test\\1'

# %%
for filename in os.listdir(test_dst):
    if filename != '0' and filename != '1':
            
        if int(filename[len(str(filename)) - 5]) == 1:
            shutil.move(test_dst + '\\' + filename, test_1  )
        if int(filename[len(str(filename)) - 5]) == 0:
            shutil.move(test_dst + '\\' + filename, test_0  )

# %%
for filename in os.listdir(train_dst):
    if filename != '0' and filename != '1':
            
        if int(filename[len(str(filename)) - 5]) == 1:
            shutil.move(train_dst + '\\' + filename, train_1  )
        if int(filename[len(str(filename)) - 5]) == 0:
            shutil.move(train_dst + '\\' + filename, train_0  )

# %%
train_dst
# Out:
# 'C:\\Users\\Machine\\Downloads\\try_sign_detection\\327\\final_dataset_v1\\train\\'

# %%
# Out:
# 4657
